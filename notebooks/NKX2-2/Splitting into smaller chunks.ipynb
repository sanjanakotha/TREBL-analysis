# %%
from trebl_tools import preprocess

# %%
# Split AD t = 5
preprocess.split_fastq(
    input_fastq="/global/scratch/projects/fc_mvslab/OpenProjects/Caitlin/TL4B2/puro_only/r5_RTBC_Puro_Only_R1_T4_S102.assembled.fastq",
    output_dir="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/NKX2-2_trebl_exp_chunks/RT_puro_only/",
    chunks=[50, 100, 200, 400, 600, 800, 1000]
)
# Out:
# Running: bash /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/trebl_tools/src/trebl_tools/savio_jobs/split_fastq.sh -i /global/scratch/projects/fc_mvslab/OpenProjects/Caitlin/TL4B2/puro_only/r5_RTBC_Puro_Only_R1_T4_S102.assembled.fastq -o /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/NKX2-2_trebl_exp_chunks/RT_puro_only -c 50,100,200,400,600,800,1000 -j 24
# Splitting into 50 chunks...
# Splitting into 100 chunks...
# Splitting into 200 chunks...
# Splitting into 400 chunks...
# Splitting into 600 chunks...
# Splitting into 800 chunks...
# Splitting into 1000 chunks...
# All splits completed!
# Done!

# %%
# Split AD t = 5
preprocess.split_fastq(
    input_fastq="/global/scratch/projects/fc_mvslab/OpenProjects/Caitlin/TL4B2/puro_only/r9_RTBC_Puro_Only_R1_T24_S106.assembled.fastq",
    output_dir="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/NKX2-2_trebl_exp_chunks/RT_puro_only/",
    chunks=[50, 100, 200, 400, 600, 800, 1000]
)
# Out:
# Running: bash /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/trebl_tools/src/trebl_tools/savio_jobs/split_fastq.sh -i /global/scratch/projects/fc_mvslab/OpenProjects/Caitlin/TL4B2/puro_only/r9_RTBC_Puro_Only_R1_T24_S106.assembled.fastq -o /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/NKX2-2_trebl_exp_chunks/RT_puro_only -c 50,100,200,400,600,800,1000 -j 24
# Splitting into 50 chunks...
# Splitting into 100 chunks...
# Splitting into 200 chunks...
# Splitting into 400 chunks...
# Splitting into 600 chunks...
# Splitting into 800 chunks...
# Splitting into 1000 chunks...
# All splits completed!
# Done!
