# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb
from concurrent.futures import ThreadPoolExecutor, as_completed
import dask.dataframe as dd
import sys
import glob
import os

sys.path.append("../../scripts")
# %aimport initial_map
# %aimport map_refiner
# %aimport complexity
# %aimport finder
# %aimport preprocess
# %aimport complexity
# %aimport plotting
# %aimport umi_deduplicate

import glob
from tqdm import tqdm  # progress bar

# %%
# umi_deduplicate.run_fastp("../data/fastp_test/", "../data/fastp_test_output/", script_path="../savio_jobs/fastp.sh")
# Out:
# Submitted batch job 30779655
# Submitted SLURM array job for 2 files using /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/savio_jobs/fastp.sh.

# %%
test_seq = finder.Barcode(name = "AD",
                        preceder = "",
                       post = "",
                       length = 10)

# %%
test_mapper = initial_map.InitialMapper(db_path = "/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/duckdb/test.db",
                                       step_name = "test", #Should include time point, replicate (don't need to specify BC type(s))
                                       seq_file = "/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/fastp_test_output/SRR000001_1_fastp.fastq.gz",
                                       bc_objects = [test_seq],
                                       reverse_complement = True,
                                        test_n_reads = 50)

# %%
test_mapper.create_map()
# Out:
# Reading 1 FASTQ/TXT file(s)...
# Done in 0.33 seconds.
#
# Reverse complement of sequences...
# Done in 0.01 seconds.
#
# Extracting 1 barcodes...
# (.{1,10})
# Done in 0.01 seconds.
#
# Extracting UMIs (0 bases)...
# Done in 0.00 seconds.
#
# Done in 0.01 seconds.
#
# Mapping complete.

# %%
test_mapper.preview_map()
# Out:
# test_AD_initial
# Total rows: 50
#            AD  AD_qual  Designed
# 0  ATTCTTGTGA     True         1
# 1  TTTTTCTGCC     True         1
# 2  TGGGCATTTA     True         1
# 3  AAAGTGTTCA     True         1
# 4  AAATTGGACC     True         1

# %%
# Seems like my mapper works on fastq gz files too yay!
