# %%
from trebl_tools import preprocess

# %% [markdown]
# # Splitting files

# %% [markdown]
# ## 1. RT

# %%
RT_files = ["global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_RP_fastp/RP_2_2_S32_R1_001_fastp.fastq.gz",

# %%
# Split RT t = 30
preprocess.split_fastq(
    input_fastq="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/RPTR_1_30_S5_R1_001_fastp.fastq.gz",
    output_dir="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/chunks",
    chunks=[400, 600, 800, 1000]
)
# Out:
# Running: bash /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/trebl_tools/src/trebl_tools/savio_jobs/split_fastq.sh -i /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/RPTR_1_30_S5_R1_001_fastp.fastq.gz -o /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/chunks -c 400,600,800,1000 -j 24
# Splitting into 400 chunks...
# Splitting into 600 chunks...
# Splitting into 800 chunks...
# Splitting into 1000 chunks...
# All splits completed!
# Done!

# %%
# Split RT t = 5
preprocess.split_fastq(
    input_fastq="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/RPTR_1_5_S2_R1_001_fastp.fastq.gz",
    output_dir="/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/chunks",
    chunks=[400, 600, 800, 1000]
)
# Out:
# Running: bash /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/trebl_tools/src/trebl_tools/savio_jobs/split_fastq.sh -i /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/RPTR_1_5_S2_R1_001_fastp.fastq.gz -o /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/GCN4_pool_C_UMI_RPTR_fastp/chunks -c 400,600,800,1000 -j 24
# Splitting into 400 chunks...
# Splitting into 600 chunks...
# Splitting into 800 chunks...
# Splitting into 1000 chunks...
# All splits completed!
# Done!

# %% [markdown]
# ## 2. AD

# %%
AD_file_paths = ["/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_2_2_S2_R1_001_fastp.fastq.gz",
                 "/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_2_10_S4_R1_001_fastp.fastq.gz",
                 "/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_2_40_S8_R1_001_fastp.fastq.gz"]

# %%
AD_output_path = "/global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_chunks"

# %%
for AD_file_path in AD_file_paths:
    preprocess.split_fastq(
        input_fastq=AD_file_path,
        output_dir=AD_output_path,
        chunks=[2,4,8,32, 64, 128, 256, 512]
    )
# Out:
# Running: bash /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/trebl_tools/src/trebl_tools/savio_jobs/split_fastq.sh -i /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_2_2_S2_R1_001_fastp.fastq.gz -o /global/scratch/projects/fc_mvslab/OpenProjects/Sanjana/TREBL/data/ChopTF/TREBL_ChopTF_AD_fastp/AD_chunks -c 2,4,8,32,64,128,256,512 -j 24
# Splitting into 2 chunks...
# Splitting into 4 chunks...
# Splitting into 8 chunks...
# Splitting into 32 chunks...
# Splitting into 64 chunks...
# Splitting into 128 chunks...
# Splitting into 256 chunks...
# Splitting into 512 chunks...
# All splits completed!
# Done!
# ...
